# %%
import pandas as pd

# NYC Squirrel Census 2018 dataset
url = "https://data.cityofnewyork.us/api/views/vfnx-vebw/rows.csv?accessType=DOWNLOAD"
df_squirrels = pd.read_csv(url)
df_squirrels.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2 -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3 -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4 -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
#
#    Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 0                        3    NaN               NaN                 NaN  ...
# 1                        4    NaN               NaN                 NaN  ...
# 2                        8    NaN              Gray                 NaN  ...
# 3                       14  Adult              Gray                 NaN  ...
# 4                        5  Adult              Gray            Cinnamon  ...
#
#     Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# ...

# %%
import pandas as pd

# Load the dataset from the URL
url = 'https://data.cityofnewyork.us/api/views/vfnx-vebw/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(url)

# Get the number of rows and columns
num_rows, num_columns = df.shape

print(f'Number of rows: {num_rows}')
print(f'Number of columns: {num_columns}')
# Out:
# Number of rows: 3023
# Number of columns: 31

# %% [markdown]
# Question 2.2:
# Variables - Represents the columns in a dataset, the features/attributes that are being measured. In the case of the squirrel dataset, the 'variables' would be the many different observations of each unique squirrel, such as their fur color, age, and their general behaviours.
#
# Observations - Represents the rows in a dataset, the individual data point for the variable being checked. In the case of the squirrel dataset, the 'observations' would represent the detailed observations of each unique squirrel studied.

# %%
import pandas as pd

# Load the dataset
url = 'https://data.cityofnewyork.us/api/views/vfnx-vebw/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(url)

# Get the count of unique values for each categorical variable
for column in df.select_dtypes(include=['object']).columns:
    print(f'\nSummary for {column}:')
    print(df[column].value_counts())
# Out:
# Summary for Unique Squirrel ID:
# Unique Squirrel ID
# 7D-PM-1010-01     2
# 40B-AM-1019-06    2
# 37E-PM-1006-03    2
# 4C-PM-1010-05     2
# 1F-AM-1010-04     2
#                  ..
# 13F-AM-1007-01    1
# 12D-AM-1013-02    1
# 2F-AM-1006-03     1
# 9H-PM-1018-04     1
# 5E-PM-1012-01     1
# Name: count, Length: 3018, dtype: int64
#
# Summary for Hectare:
# Hectare
# 14D    32
# 32E    30
# 14E    28
# 01B    27
# 07H    26
#        ..
# 11C     1
# 23D     1
# 26B     1
# 24B     1
# 30F     1
# Name: count, Length: 339, dtype: int64
#
# Summary for Shift:
# Shift
# PM    1676
# AM    1347
# Name: count, dtype: int64
#
# Summary for Age:
# Age
# Adult       2568
# Juvenile     330
# ?              4
# Name: count, dtype: int64
#
# Summary for Primary Fur Color:
# Primary Fur Color
# Gray        2473
# Cinnamon     392
# Black        103
# Name: count, dtype: int64
#
# Summary for Highlight Fur Color:
# Highlight Fur Color
# Cinnamon                  767
# ...

# %%
import pandas as pd

# Load the dataset
url = 'https://data.cityofnewyork.us/api/views/vfnx-vebw/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(url)

print(df.shape)
print(df.describe())
# Out:
# (3023, 31)
#                  X            Y          Date  Hectare Squirrel Number
# count  3023.000000  3023.000000  3.023000e+03              3023.000000
# mean    -73.967184    40.780853  1.011949e+07                 4.123718
# std       0.007726     0.010285  4.246671e+04                 3.096492
# min     -73.981159    40.764911  1.006202e+07                 1.000000
# 25%     -73.973102    40.771676  1.008202e+07                 2.000000
# 50%     -73.968594    40.778166  1.012202e+07                 3.000000
# 75%     -73.960189    40.791219  1.014202e+07                 6.000000
# max     -73.949722    40.800119  1.020202e+07                23.000000

# %% [markdown]
# Question 4:
# The reason why there is a discrepancy between the amount of rows and columns given by df.shape and df.describe() is due to the difference in their functions. df.describe() only analyzes the numerical columns of a DataFrame for statistical purposes, hence why the non-numerical variables (age and fur-colour for example) are not present. df.shape is used to provide the dimensions of a DataFrame, so it counts every row and column. This is also why values in the 'count' column could be different, because the count column only reports non-null entries (rows). However, since the numerical observations of the squirrel dataset contains no null entries, each count is equal to the total rows of the dataset.

# %% [markdown]
# Question 5: The difference between an attribute and a method is the way that they interact with objects. Attributes directly access the data of an object without any additional computations, like df.shape, which directly pulls the dimensions of a DataFrame. Methods, indicated by parentheses, perform computations based on the data of an object in order to generate and return results that are not available or held within an object. df.describe() is an example of this, as it accesses a DataFrame and generates statistics such as mean and percentages that are not locally available within the DataFrame.

# %% [markdown]
# Chat Summary (https://chatgpt.com/share/8c468e40-2624-4487-b78d-83e63ae236a5):
#
# Summary
# Dataset Insights:
#
# You provided a link to a dataset of detailed observations of squirrels found in Central Park and asked about determining the number of rows and columns in the dataset.
# We discussed using the df.shape attribute to get the number of rows and columns and df.describe() for summary statistics of numeric columns.
# Data Discrepancy:
#
# You noted a discrepancy between the number of rows and columns reported by df.shape and df.describe().
# We explained that df.describe() provides statistics for numeric columns only and might not include all rows if there are missing values.
# Attributes vs. Methods:
#
# We discussed the difference between attributes and methods in Python:
# Attributes: Variables that store data or state related to an object. Example: df.shape.
# Methods: Functions that perform operations or computations. Example: df.describe().
# Python Objects:
#
# We clarified that df is an object in Python, specifically an instance of the pandas.DataFrame class.
# As an object, df has attributes (like shape) and methods (like describe()) that are defined by the DataFrame class.
# Feel free to reach out if you have any more questions or need further assistance!
